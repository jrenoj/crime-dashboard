# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/Users/jrenoj/Desktop/crime-dashboard/data/processed/processed.csv')
pd.set_option('display.max_columns', None)
df.head()
# Out:
#        DR_NO                 DATE OCC    AREA NAME  \
# 0  211507896  2020 Nov 07 12:00:00 AM  N Hollywood
# 1  201516622  2020 Oct 18 12:00:00 AM  N Hollywood
# 2  240913563  2020 Oct 30 12:00:00 AM     Van Nuys
# 3  210704711  2020 Dec 24 12:00:00 AM     Wilshire
# 4  201418201  2020 Sep 29 12:00:00 AM      Pacific
#
#                                          Crm Cd Desc  Vict Age Vict Sex  \
# 0                                  THEFT OF IDENTITY        31        M
# 1     ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT        32        M
# 2                                  THEFT OF IDENTITY        30        M
# 3  THEFT FROM MOTOR VEHICLE - GRAND ($950.01 AND ...        47        F
# 4    THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)        63        M
#
#   Vict Descent      LAT       LON  Year      Month       Day   Time
# 0            H  34.2124 -118.4092  2020   November  Saturday   8:00
# 1            H  34.1993 -118.4203  2020    October    Sunday  18:00
# ...

# %%
df.groupby('Year').size().plot(kind='bar', figsize=(10, 6))
# Out:
# <Axes: xlabel='Year'>

# %%
df.groupby('AREA NAME').size().sort_values(ascending=False).plot(kind='bar', figsize=(10, 6))
# Out:
# <Axes: xlabel='AREA NAME'>

# %%
df.groupby("Month").size().sort_values(ascending=False).plot(kind='bar', figsize=(10, 6))
# Out:
# <Axes: xlabel='Month'>

# %%
df.groupby("Day").size().sort_values(ascending=False).plot(kind='bar', figsize=(10, 6))
# Out:
# <Axes: xlabel='Day'>

# %%
df.groupby("Vict Sex").size().sort_values(ascending=False).plot(kind='bar', figsize=(10, 6))
# Out:
# <Axes: xlabel='Vict Sex'>

# %%
df.groupby("Vict Age").size().sort_values(ascending=False).plot(kind='hist', figsize=(10, 6), bins=20, edgecolor='black')

# why is there a big sike at 250000???
# Out:
# <Axes: ylabel='Frequency'>

# %%
df[["Vict Age"] > 160]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 df[["Vict Age"] > 160]
#
# TypeError: '>' not supported between instances of 'list' and 'int'
