# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/Users/jrenoj/Desktop/crime-dashboard/data/raw/export.csv')
pd.set_option('display.max_columns', None)
df.head()
# Out:
#        DR_NO                Date Rptd                 DATE OCC  TIME OCC  \
# 0  211507896  2021 Apr 11 12:00:00 AM  2020 Nov 07 12:00:00 AM       845
# 1  201516622  2020 Oct 21 12:00:00 AM  2020 Oct 18 12:00:00 AM      1845
# 2  240913563  2024 Dec 10 12:00:00 AM  2020 Oct 30 12:00:00 AM      1240
# 3  210704711  2020 Dec 24 12:00:00 AM  2020 Dec 24 12:00:00 AM      1310
# 4  201418201  2020 Oct 03 12:00:00 AM  2020 Sep 29 12:00:00 AM      1830
#
#    AREA    AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0    15  N Hollywood         1502         2     354
# 1    15  N Hollywood         1521         1     230
# 2     9     Van Nuys          933         2     354
# 3     7     Wilshire          782         1     331
# 4    14      Pacific         1454         1     420
#
#                                          Crm Cd Desc  \
# 0                                  THEFT OF IDENTITY
# 1     ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT
# 2                                  THEFT OF IDENTITY
# 3  THEFT FROM MOTOR VEHICLE - GRAND ($950.01 AND ...
# 4    THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)
#
#                                    Mocodes  Vict Age Vict Sex Vict Descent  \
# 0                                     0377        31        M            H
# 1  0416 0334 2004 1822 1414 0305 0319 0400        32        M            H
# 2                                     0377        30        M            W
# 3                                     0344        47        F            A
# 4                      1300 0344 1606 2032        63        M            H
#
#    Premis Cd             Premis Desc  Weapon Used Cd  \
# 0      501.0  SINGLE FAMILY DWELLING             NaN
# 1      102.0                SIDEWALK           200.0
# 2      501.0  SINGLE FAMILY DWELLING             NaN
# 3      101.0                  STREET             NaN
# 4      103.0                   ALLEY             NaN
#
#                         Weapon Desc Status  Status Desc  Crm Cd 1  Crm Cd 2  \
# 0                               NaN     IC  Invest Cont     354.0       NaN
# 1  KNIFE WITH BLADE 6INCHES OR LESS     IC  Invest Cont     230.0       NaN
# 2                               NaN     IC  Invest Cont     354.0       NaN
# 3                               NaN     IC  Invest Cont     331.0       NaN
# 4                               NaN     IC  Invest Cont     420.0       NaN
#
#    Crm Cd 3  Crm Cd 4                                  LOCATION Cross Street  \
# 0       NaN       NaN   7800    BEEMAN                       AV          NaN
# 1       NaN       NaN           ATOLL                        AV     N  GAULT
# 2       NaN       NaN  14600    SYLVAN                       ST          NaN
# 3       NaN       NaN   6000    COMEY                        AV          NaN
# 4       NaN       NaN                   4700    LA VILLA MARINA          NaN
#
#        LAT       LON
# 0  34.2124 -118.4092
# 1  34.1993 -118.4203
# 2  34.1847 -118.4509
# 3  34.0339 -118.3747
# 4  33.9813 -118.4350

# %%
new = df[["DR_NO", "DATE OCC", "TIME OCC", "AREA NAME", "Crm Cd Desc", "Vict Age", "Vict Sex", "Vict Descent", "LAT", "LON"]]
new.head()
# Out:
#        DR_NO                 DATE OCC  TIME OCC    AREA NAME  \
# 0  211507896  2020 Nov 07 12:00:00 AM       845  N Hollywood
# 1  201516622  2020 Oct 18 12:00:00 AM      1845  N Hollywood
# 2  240913563  2020 Oct 30 12:00:00 AM      1240     Van Nuys
# 3  210704711  2020 Dec 24 12:00:00 AM      1310     Wilshire
# 4  201418201  2020 Sep 29 12:00:00 AM      1830      Pacific
#
#                                          Crm Cd Desc  Vict Age Vict Sex  \
# 0                                  THEFT OF IDENTITY        31        M
# 1     ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT        32        M
# 2                                  THEFT OF IDENTITY        30        M
# 3  THEFT FROM MOTOR VEHICLE - GRAND ($950.01 AND ...        47        F
# 4    THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)        63        M
#
#   Vict Descent      LAT       LON
# 0            H  34.2124 -118.4092
# 1            H  34.1993 -118.4203
# 2            W  34.1847 -118.4509
# 3            A  34.0339 -118.3747
# 4            H  33.9813 -118.4350

# %%
new["Year"] = pd.to_datetime(new["DATE OCC"]).dt.year
new["Month"] = pd.to_datetime(new["DATE OCC"]).dt.month_name()
new["Day"] = pd.to_datetime(new["DATE OCC"]).dt.day_name()
new["Time"] = (
    pd.to_datetime(new["TIME OCC"].astype(str).str.zfill(4), format="%H%M")
    .dt.hour.astype(str)
    + ":00"
)
# Out:
# /var/folders/zl/5qwj97qj4y5d7tj4vl4r46d80000gn/T/ipykernel_8848/1068638057.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   new["Year"] = pd.to_datetime(new["DATE OCC"]).dt.year
# /var/folders/zl/5qwj97qj4y5d7tj4vl4r46d80000gn/T/ipykernel_8848/1068638057.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new["Year"] = pd.to_datetime(new["DATE OCC"]).dt.year
# /var/folders/zl/5qwj97qj4y5d7tj4vl4r46d80000gn/T/ipykernel_8848/1068638057.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   new["Month"] = pd.to_datetime(new["DATE OCC"]).dt.month_name()
# /var/folders/zl/5qwj97qj4y5d7tj4vl4r46d80000gn/T/ipykernel_8848/1068638057.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new["Month"] = pd.to_datetime(new["DATE OCC"]).dt.month_name()
# /var/folders/zl/5qwj97qj4y5d7tj4vl4r46d80000gn/T/ipykernel_8848/1068638057.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   new["Day"] = pd.to_datetime(new["DATE OCC"]).dt.day_name()
# /var/folders/zl/5qwj97qj4y5d7tj4vl4r46d80000gn/T/ipykernel_8848/1068638057.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new["Day"] = pd.to_datetime(new["DATE OCC"]).dt.day_name()
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 4
#       2 new["Month"] = pd.to_datetime(new["DATE OCC"]).dt.month_name()
#       3 new["Day"] = pd.to_datetime(new["DATE OCC"]).dt.day_name()
# ----> 4 new["Time"] = pd.to_datetime(new["TIME OCC"], format='%H%M').dt.time
#
# File ~/Desktop/crime-dashboard/.venv/lib/python3.9/site-packages/pandas/core/tools/datetimes.py:1068, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1066             result = arg.tz_localize("utc")
#    1067 elif isinstance(arg, ABCSeries):
# -> 1068     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1069     if not cache_array.empty:
#    1070         result = arg.map(cache_array)
#
# File ~/Desktop/crime-dashboard/.venv/lib/python3.9/site-packages/pandas/core/tools/datetimes.py:249, in _maybe_cache(arg, format, cache, convert_listlike)
#     247 unique_dates = unique(arg)
#     248 if len(unique_dates) < len(arg):
# --> 249     cache_dates = convert_listlike(unique_dates, format)
#     250     # GH#45319
#     251     try:
#
# File ~/Desktop/crime-dashboard/.venv/lib/python3.9/site-packages/pandas/core/tools/datetimes.py:435, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     433 # `format` could be inferred, or user didn't ask for mixed-format parsing.
#     434 if format is not None and format != "mixed":
# --> 435     return _array_strptime_with_fallback(arg, name, utc, format, exact, errors)
#     437 result, tz_parsed = objects_to_datetime64(
#     438     arg,
#     439     dayfirst=dayfirst,
#    (...)
#     443     allow_object=True,
#     444 )
#     446 if tz_parsed is not None:
#     447     # We can take a shortcut since the datetime64 numpy array
#     448     # is in UTC
#
# File ~/Desktop/crime-dashboard/.venv/lib/python3.9/site-packages/pandas/core/tools/datetimes.py:469, in _array_strptime_with_fallback(arg, name, utc, fmt, exact, errors)
#     458 def _array_strptime_with_fallback(
#     459     arg,
#     460     name,
#    (...)
#     464     errors: str,
#     465 ) -> Index:
#     466     """
#     467     Call array_strptime, with fallback behavior depending on 'errors'.
#     468     """
# --> 469     result, tz_out = array_strptime(arg, fmt, exact=exact, errors=errors, utc=utc)
#     470     if tz_out is not None:
#     471         unit = np.datetime_data(result.dtype)[0]
#
# File pandas/_libs/tslibs/strptime.pyx:501, in pandas._libs.tslibs.strptime.array_strptime()
#
# File pandas/_libs/tslibs/strptime.pyx:451, in pandas._libs.tslibs.strptime.array_strptime()
#
# File pandas/_libs/tslibs/strptime.pyx:583, in pandas._libs.tslibs.strptime._parse_with_format()
#
# ValueError: time data "1" doesn't match format "%H%M", at position 10. You might want to try:
#     - passing `format` if your strings have a consistent format;
#     - passing `format='ISO8601'` if your strings are all ISO8601 but not necessarily in exactly the same format;
#     - passing `format='mixed'`, and the format will be inferred for each element individually. You might want to use `dayfirst` alongside this.
